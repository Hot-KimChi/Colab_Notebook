# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# >### git commit and push

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://Hot-Kimchi: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@github.com/Hot-Kimchi/Deep_Learning_with_Python.git
# Out:
# fatal: destination path 'Deep_Learning_with_Python' already exists and is not an empty directory.

# %%
cd /content/drive/MyDrive/Colab Notebooks/Deep_Learning_with_Python
# Out:
# /content/drive/MyDrive/Colab Notebooks/Deep_Learning_with_Python

# %%
# !git config --global user.email 'inseop.hwang@hotmail.com'
# !git config --global user.name 'Hot-Kimchi'

# %%
# !git add .
# !git status
# !git add --all
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   9_1_3EA_computer_vision.ipynb

# %%
# !git commit -m '3EA computer vision'
# !git push
# Out:
# [main 4fcba99] 3EA computer vision
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite 9_1_3EA_computer_vision.ipynb (93%)
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/Hot-Kimchi/Deep_Learning_with_Python.git/'

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import os

input_dir = 'images'
